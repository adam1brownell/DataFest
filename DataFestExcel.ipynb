# %%
import pandas as pd
import os
os.chdir("C:\\Users\\adam1brownell\\Desktop")
path = os.getcwd()
df = pd.read_csv('data.txt', sep="\t", header=0)

# %%
headers = list(df)

# %%
def correlate(data,given,checking):
    one = float(data['checking'].shape[0])/float(data.shape[0])
    two = float(data['given'].shape[0])/float(data.shape[0])
    return float(one/two)*100
headers
# Out:
# ['date_time',
#  'site_name',
#  'user_location_country',
#  'user_location_region',
#  'user_location_city',
#  'user_location_latitude',
#  'user_location_longitude',
#  'orig_destination_distance',
#  'user_id',
#  'is_mobile',
#  'is_package',
#  'channel',
#  'srch_ci',
#  'srch_co',
#  'srch_adults_cnt',
#  'srch_children_cnt',
#  'srch_rm_cnt',
#  'srch_destination_id',
#  'hotel_country',
#  'is_booking',
#  'hotel_id',
#  'prop_is_branded',
#  'prop_starrating',
#  'distance_band',
#  'hist_price_band',
#  'popularity_band',
#  'cnt']

# %%
from collections import Counter
bookers = df[df['is_booking'] == 1]
lookers = df[df['is_booking'] == 0]
packers = bookers[bookers['is_package'] == 1]

# %%
def dd(x):
    big = float(sum(x.values()))
    for key,value in x.items():
        print key, ": ", float(value)/big*100, "%"
    print "\n"

# %%
x = Counter(bookers['cnt'])
dd(x)
# Out:
# 1 :  98.7913183494 %
# 2 :  1.12493951377 %
# 3 :  0.0638233969064 %
# 4 :  0.0127229647428 %
# 5 :  0.00417146385009 %
# 6 :  0.00135572575128 %
# 7 :  0.000625719577514 %
# 8 :  0.000625719577514 %
# 9 :  0.000208573192505 %
# 10 :  0.000104286596252 %
# 12 :  0.000104286596252 %

# %%
print"Golden Data:\n"
print "Channels:"
dd(Counter(packers['channel']))
print "Mobile?"
dd(Counter(packers['is_mobile']))
print "Party Size:"
dd(Counter(packers['srch_adults_cnt']))
print "Hotal Proximity:"
dd(Counter(packers['distance_band']))
print "Star Rating:"
dd(Counter(packers['prop_starrating']))
print "Branded?"
dd(Counter(packers['prop_is_branded']))
# Out:
# Golden Data:
#
# Channels:
# 448 :  0.6409063416 %
# 417 :  0.00465267761597 %
# 386 :  1.9517982599 %
# 355 :  3.22081607965 %
# 324 :  3.37086493277 %
# 293 :  6.92202112316 %
# 262 :  9.4100404783 %
# 231 :  12.8646536082 %
# 541 :  40.3049830177 %
# 510 :  21.0010235891 %
# 479 :  0.308239892058 %
#
#
# Mobile?
# 0 :  90.4701530731 %
# 1 :  9.52984692691 %
#
#
# Party Size:
# 0 :  0.309403061462 %
# 1 :  30.9647327037 %
# 2 :  59.8869399339 %
# 3 :  4.82133717955 %
# 4 :  3.23244777369 %
# 5 :  0.430372679477 %
# 6 :  0.353603498814 %
# 8 :  0.00116316940399 %
#
#
# Hotal Proximity:
# C :  29.5514818778 %
# VC :  18.5385939608 %
# M :  37.302842786 %
# VF :  4.11878285954 %
# F :  10.4882985158 %
#
#
# Star Rating:
# 0.0 :  0.765365467827 %
# 1.0 :  0.0651374866236 %
# 2.0 :  2.95561345554 %
# 3.0 :  22.6352766017 %
# 4.0 :  53.737263295 %
# 5.0 :  19.8413436933 %
#
#
# Branded?
# 0 :  28.7756478854 %
# 1 :  71.2243521146 %

# %%
couples = packers[packers['srch_adults_cnt'] == 2]

# %%
print "Package Couples Values:\n"
print "Kids:"
dd(Counter(couples['srch_children_cnt']))
print "Mobile?"
dd(Counter(couples['is_mobile']))
print "Branded?"
dd(Counter(couples['prop_is_branded']))
print "Hotal Proximity:"
dd(Counter(couples['distance_band']))
print "Channel"
dd(Counter(couples['channel']))
# Out:
# Package Couples Values:
#
# Kids:
# 0 :  86.5866449132 %
# 1 :  6.63092879618 %
# 2 :  5.92005593754 %
# 3 :  0.708930583071 %
# 4 :  0.153439770035 %
#
#
# Mobile?
# 0 :  89.2689274754 %
# 1 :  10.7310725246 %
#
#
# Branded?
# 0 :  29.4079944062 %
# 1 :  70.5920055938 %
#
#
# Hotal Proximity:
# C :  29.60804879 %
# VC :  18.3253700035 %
# M :  37.4043429282 %
# VF :  4.32933224566 %
# F :  10.3329060327 %
#
#
# Channel
# 448 :  0.625412733559 %
# 417 :  0.00194227557006 %
# 386 :  2.18311774075 %
# 355 :  3.62234393816 %
# 324 :  3.56990249777 %
# 293 :  6.94363516296 %
# 262 :  9.80266480208 %
# 231 :  13.0326690751 %
# 541 :  39.0688730917 %
# 510 :  20.861981898 %
# 479 :  0.287456784369 %

# %%
us_couples = couples[couples['hotel_country'] == 'UNITED STATES OF AMERICA']

# %%
funnel = packers[packers['channel'] == 541]
print "541 Marketing Demographics:"
print "Mobile?"
dd(Counter(funnel['is_mobile']))
print "Branded?"
dd(Counter(funnel['prop_is_branded']))
print "Star Rating:"
dd(Counter(funnel['prop_starrating']))
# Out:
# 541 Marketing Demographics:
# Mobile?
# 0 :  90.0724365819 %
# 1 :  9.92756341808 %
#
#
# Branded?
# 0 :  28.2531528672 %
# 1 :  71.7468471328 %
#
#
# Star Rating:
# 0.0 :  0.718593979972 %
# 1.0 :  0.0606043115639 %
# 2.0 :  2.80222792993 %
# 3.0 :  21.3817783037 %
# 4.0 :  53.649245332 %
# 5.0 :  21.3875501429 %

# %%
print "Hotel Location:"
sorted(Counter(funnel['hotel_country']).items())
# Out:
# Hotel Location:
# [('ALBANIA', 2),
#  ('ALGERIA', 1),
#  ('ANGUILLA', 1),
#  ('ANTIGUA AND BARBUDA', 35),
#  ('ARGENTINA', 83),
#  ('ARMENIA', 1),
#  ('ARUBA', 223),
#  ('AUSTRALIA', 59),
#  ('AUSTRIA', 126),
#  ('AZERBAIJAN', 1),
#  ('BAHAMAS', 244),
#  ('BAHRAIN', 25),
#  ('BANGLADESH', 1),
#  ('BARBADOS', 62),
#  ('BELARUS', 1),
#  ('BELGIUM', 26),
#  ('BELIZE', 36),
#  ('BERMUDA', 45),
#  ('BOLIVIA', 1),
#  ('BONAIRE, SINT EUSTATIUS AND SABA', 5),
#  ('BOSNIA AND HERZEGOVINA', 1),
#  ('BOTSWANA', 1),
#  ('BRAZIL', 105),
#  ('BRITISH VIRGIN ISLANDS', 4),
#  ('BULGARIA', 12),
#  ('CAMBODIA', 20),
#  ('CANADA', 1289),
#  ('CAPE VERDE', 1),
#  ('CAYMAN ISLANDS', 68),
#  ('CHILE', 28),
#  ('CHINA', 80),
#  ('COLOMBIA', 163),
#  ('COOK ISLANDS', 1),
#  ('COSTA RICA', 164),
#  ('CROATIA', 15),
#  ('CURACAO', 50),
#  ('CYPRUS', 30),
#  ('CZECH REPUBLIC', 77),
#  ('DENMARK', 28),
#  ('DOMINICA', 1),
#  ('DOMINICAN REPUBLIC', 1046),
#  ('ECUADOR', 26),
#  ('EGYPT', 67),
# ...

# %%
"All Data"
couples = df[df['srch_adults_cnt'] == 2]
print "Kids:"
dd(Counter(couples['srch_children_cnt']))
print "Mobile?"
dd(Counter(couples['is_mobile']))
print "Branded?"
dd(Counter(couples['prop_is_branded']))
print "Hotal Proximity:"
dd(Counter(couples['distance_band']))
print "Channel"
dd(Counter(couples['channel']))
# Out:
# Kids:
# 0 :  82.0786729108 %
# 1 :  6.68838140585 %
# 2 :  9.4036725566 %
# 3 :  1.40385502903 %
# 4 :  0.359447295684 %
# 5 :  0.0418620869725 %
# 6 :  0.0199887891226 %
# 7 :  0.00184551889168 %
# 8 :  0.00180652905594 %
# 9 :  0.000467878028877 %
#
#
# Mobile?
# 0 :  75.80448053 %
# 1 :  24.19551947 %
#
#
# Branded?
# 0 :  38.5665750795 %
# 1 :  61.4334249205 %
#
#
# Hotal Proximity:
# C :  25.5710288885 %
# VC :  14.8192177781 %
# M :  38.5642356894 %
# VF :  6.96077739494 %
# F :  14.0847402491 %
#
#
# Channel
# 448 :  1.06962116046 %
# 417 :  0.0150630732074 %
# 386 :  1.86874383717 %
# 355 :  1.07145368274 %
# 324 :  7.22211326729 %
# 293 :  13.6271295436 %
# 262 :  8.93134968645 %
# 231 :  13.324308486 %
# 541 :  37.8949101759 %
# 510 :  14.7246934197 %
# 479 :  0.250613667523 %

# %%
print "Channel"
dd(Counter(bookers['srch_adults_cnt']))
# Out:
# Channel
# 0 :  0.0544376032437 %
# 1 :  24.5957851529 %
# 2 :  64.330021191 %
# 3 :  4.81950075921 %
# 4 :  4.69581685605 %
# 5 :  0.529045902788 %
# 6 :  0.670771387095 %
# 7 :  0.0912507717208 %
# 8 :  0.18615157431 %
# 9 :  0.0272188016219 %

# %%
"All Data"
couples = bookers[bookers['srch_adults_cnt'] == 2]
print "Kids:"
dd(Counter(couples['srch_children_cnt']))
print "Mobile?"
dd(Counter(couples['is_mobile']))
print "Branded?"
dd(Counter(couples['prop_is_branded']))
print "Hotal Proximity:"
dd(Counter(couples['distance_band']))
print "Channel"
dd(Counter(couples['hotel_country']))
# Out:
# Kids:
# 0 :  83.9212590256 %
# 1 :  6.31198752387 %
# 2 :  8.27937710138 %
# 3 :  1.10641346955 %
# 4 :  0.318063476521 %
# 5 :  0.0406900777813 %
# 6 :  0.0194534236404 %
# 7 :  0.000972671182022 %
# 8 :  0.0016211186367 %
# 9 :  0.00016211186367 %
#
#
# Mobile?
# 0 :  76.5388468659 %
# 1 :  23.4611531341 %
#
#
# Branded?
# 0 :  32.3302931955 %
# 1 :  67.6697068045 %
#
#
# Hotal Proximity:
# C :  26.4216399885 %
# VC :  15.1748052226 %
# M :  38.6322297838 %
# VF :  6.75925415574 %
# F :  13.0120708494 %
#
#
# Channel
# PORTUGAL :  0.29504359188 %
# INDIA :  0.211718093954 %
# MONTENEGRO :  0.00340434913708 %
# NEW CALEDONIA :  0.00113478304569 %
# SPAIN & CANARY ISLANDS :  1.35039182437 %
# BAHAMAS :  0.135201294301 %
# SVALBARD :  0.00129689490936 %
# ARUBA :  0.11396464016 %
# LUXEMBOURG :  0.0165354100944 %
# BARBADOS :  0.0476608879191 %
# BENIN :  0.000486335591011 %
# ALGERIA :  0.00291801354607 %
# OMAN :  0.0179944168674 %
# COSTA RICA :  0.442889611548 %
# ...

# %%
#Build Domestic and International Flights
domestic = df[df['hotel_country'] == df['user_location_country']]
international = df[df['hotel_country'] != df['user_location_country']]

# %%
#Domestic Metrics
packers = domestic
print "Channels:"
dd(Counter(packers['channel']))
print "Mobile?"
dd(Counter(packers['is_mobile']))
print "Party Size:"
dd(Counter(packers['srch_adults_cnt']))
print "Hotal Proximity:"
dd(Counter(packers['distance_band']))
print "Star Rating:"
dd(Counter(packers['prop_starrating']))
print "Branded?"
dd(Counter(packers['prop_is_branded']))
print "Bookings:"
dd(Counter(packers['is_booking']))
# Out:
# Channels:
# 448 :  1.11545267995 %
# 417 :  0.0191568766268 %
# 386 :  1.41914826225 %
# 355 :  1.11242054444 %
# 324 :  5.44437811756 %
# 293 :  13.9859193847 %
# 262 :  9.21378903272 %
# 231 :  14.642151255 %
# 541 :  38.5446931331 %
# 510 :  14.2461232593 %
# 479 :  0.256767454333 %
#
#
# Mobile?
# 0 :  73.3684895192 %
# 1 :  26.6315104808 %
#
#
# Party Size:
# 0 :  0.0547961308707 %
# 1 :  17.2946789443 %
# 2 :  70.6596885048 %
# 3 :  4.91481176425 %
# 4 :  5.16789400774 %
# 5 :  0.706969604474 %
# 6 :  0.843555646917 %
# 7 :  0.102455081245 %
# 8 :  0.22353835908 %
# 9 :  0.0316119563167 %
#
#
# Hotal Proximity:
# C :  26.5278736442 %
# VC :  15.1926160192 %
# M :  38.0378289226 %
# VF :  6.74415353739 %
# F :  13.4975278766 %
#
#
# Star Rating:
# 0.0 :  0.329600904105 %
# 1.0 :  0.096468557299 %
# 2.0 :  13.2150572428 %
# 3.0 :  41.8935546284 %
# 4.0 :  36.7066592382 %
# 5.0 :  7.75865942914 %
#
#
# Branded?
# 0 :  31.3432624627 %
# 1 :  68.6567375373 %
#
#
# Bookings:
# ...

# %%
x = df[df['srch_children_cnt'] > 0]
packers = x[x['is_package'] == 1]
print "Channels:"
dd(Counter(packers['channel']))
print "Mobile?"
dd(Counter(packers['is_mobile']))
print "Party Size:"
dd(Counter(packers['srch_adults_cnt']))
print "Hotal Proximity:"
dd(Counter(packers['distance_band']))
print "Star Rating:"
dd(Counter(packers['prop_starrating']))
print "Branded?"
dd(Counter(packers['prop_is_branded']))
print "Bookings:"
dd(Counter(packers['is_booking']))
# Out:
# Channels:
# 448 :  0.673440612944 %
# 417 :  0.00566143029297 %
# 386 :  1.91679854205 %
# 355 :  1.22475608671 %
# 324 :  3.01215050778 %
# 293 :  7.61057986526 %
# 262 :  9.66810538887 %
# 231 :  12.251335154 %
# 541 :  42.6642690959 %
# 510 :  20.6477754623 %
# 479 :  0.325127853967 %
#
#
# Mobile?
# 0 :  81.8561942787 %
# 1 :  18.1438057213 %
#
#
# Party Size:
# 0 :  0.0603885897916 %
# 1 :  13.0320733506 %
# 2 :  71.3224292389 %
# 3 :  10.2151073919 %
# 4 :  4.58683690498 %
# 5 :  0.680989186668 %
# 6 :  0.0614669574665 %
# 7 :  0.0150971474479 %
# 8 :  0.0202193939034 %
# 9 :  0.00539183837425 %
#
#
# Hotal Proximity:
# C :  24.4873035686 %
# VC :  14.7011169193 %
# M :  40.1419671044 %
# VF :  6.90263148672 %
# F :  13.766980921 %
#
#
# Star Rating:
# 0.0 :  1.05410440217 %
# 1.0 :  0.0482569534496 %
# 2.0 :  2.19205189105 %
# 3.0 :  19.0984307054 %
# 4.0 :  57.5109656513 %
# 5.0 :  20.0961903966 %
#
#
# Branded?
# 0 :  33.2972978802 %
# 1 :  66.7027021198 %
#
#
# Bookings:
# ...

# %%
packers = df[df['is_mobile'] == 1]
print "Channels:"
dd(Counter(packers['channel']))
print "Mobile?"
dd(Counter(packers['is_mobile']))
print "Party Size:"
dd(Counter(packers['srch_adults_cnt']))
print "Hotal Proximity:"
dd(Counter(packers['distance_band']))
print "Star Rating:"
dd(Counter(packers['prop_starrating']))
print "Branded?"
dd(Counter(packers['prop_is_branded']))
print "Bookings:"
dd(Counter(packers['is_booking']))
print "Pack Views:"
dd(Counter(packers['is_package']))
# Out:
# Channels:
# 448 :  0.571841096419 %
# 417 :  0.0443458427123 %
# 386 :  0.639627478297 %
# 355 :  0.725867050582 %
# 324 :  4.68810783313 %
# 293 :  20.7795392355 %
# 262 :  9.87474273593 %
# 231 :  13.0173958725 %
# 541 :  35.9837212937 %
# 510 :  13.526645742 %
# 479 :  0.148165819372 %
#
#
# Mobile?
# 1 :  100.0 %
#
#
# Party Size:
# 0 :  0.0384857079209 %
# 1 :  12.1204211982 %
# 2 :  77.3736870804 %
# 3 :  4.49775735551 %
# 4 :  4.45353619651 %
# 5 :  0.60309514864 %
# 6 :  0.688254128694 %
# 7 :  0.0712359647694 %
# 8 :  0.132788160699 %
# 9 :  0.020739058588 %
#
#
# Hotal Proximity:
# C :  25.7413278317 %
# VC :  14.8209874286 %
# M :  38.7311686023 %
# VF :  6.84837794794 %
# F :  13.8581381895 %
#
#
# Star Rating:
# 0.0 :  0.92029052969 %
# 1.0 :  0.143843450447 %
# 2.0 :  12.0117801178 %
# 3.0 :  37.5708619136 %
# 4.0 :  38.7794212016 %
# 5.0 :  10.5738027869 %
#
#
# Branded?
# 0 :  36.0914480268 %
# 1 :  63.9085519732 %
#
#
# Bookings:
# 0 :  91.8624339592 %
# ...
